# %%
# Load necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data
df = pd.read_csv('data/salary_analysis/salary_data_2024.csv')

# %%
# display first few rows
df.head()
